# %% [markdown]
# # DeltaBandPFCAnalysis

# %% [markdown]
# ## Load DeltaBandPFC MAT Data

# %%
from scipy.io import loadmat
deltaBandPFCMat = loadmat('DeltaBandPFCMat.mat')

# %%
deltaBandPFCMat.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'DeltaBand'])

# %%
# deltaBandPFCMat['DeltaBand']['data']

# %%
# deltaBandPFCMat['DeltaBand']['spec']

# %%
# deltaBandPFCMat['DeltaBand']['timestamps']

# %%
# deltaBandPFCMat['DeltaBand']['freqs']

# %% [markdown]
# ## Load DataFrame

# %%
import numpy as np
import pandas as pd

# %%
data = deltaBandPFCMat['DeltaBand']['data']
timesteps = deltaBandPFCMat['DeltaBand']['timestamps']

# %%
flat_data = np.concatenate(data.all())
df = pd.DataFrame({'DeltaBandPFC': flat_data})

# %%
df['Timestep'] = range(1, len(timesteps.all()) + 1)
df.set_index('Timestep', inplace=True)

# %% [markdown]
# ## Plot Timeseries

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['DeltaBandPFC'], label='DeltaBandPFC', color='blue')
plt.title('Time Series Plot of DeltaBandPFC')
plt.xlabel('Timestep')
plt.ylabel('DeltaBandPFC Value')
plt.legend()
plt.grid(True)
plt.show()
